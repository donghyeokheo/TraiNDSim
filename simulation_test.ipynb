# %%
# !python train.py \
    --FormulaType 0 \
    --MaxPulse 1000 \
    --Gmin 0.5 \
    --Gmax 15.5 \
    --NonlinearityLTP 1.5 \
    --NonlinearityLTD 1.3 \
    --network plain \
    --weight_representation bi \
    --batch_size 200 \
    --optimizer Momentum \
    --loss CE \
    --epoch 50 \
    --learning_rate 3e-3 \
    --lr_decay 30,40 \
    --weight_decay 1e-4 \
    --data_type cifar10 \
    --data_normalization True \
    --image_RandomHorizontalFlip True
# Out:
# ------------------- Device Parameters --------------------
# Formula Type: Log modeling
# Max Pulse: 1000
# G-min: 0.5
# G-max: 15.5
# Nonlinearity LTP / LTD: 1.5 / 1.3
# cycle-to-cycle variation: 0.0
# device-to-device variation: 0.0
#
# ------------- Setting Network and Conductance ------------
# Network: plain
# Weight representation type: Bi-directional method
# Weight initialization factor: 1.0
# Fixed normalization: False
# Weight distribution scale: 1.5
# Pulse update: multi
# Delta pulse representation: Normalized Grad Pulse Update
# Cuda: cuda:0
#
# --------------------- Hyperparameters --------------------
# seed: 0
# batch size: 200
# optimizer: Momentum
# loss function: CE
# epochs: 50
# learning rate: 0.003
# learning rate decay: [30, 40]
# learning rate decay scale: 0.125
# weight decay: 0.0001
# beta: 0.9
# dampening: 0.0
#
# ---------------------- Loading Data ----------------------
# Dataset: cifar10
# root of data: /workspace/Simulator_codes/dataset
# ...
